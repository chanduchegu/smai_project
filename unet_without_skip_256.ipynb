# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !kaggle datasets download -d kumaresanmanickavelu/lyft-udacity-challenge
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading lyft-udacity-challenge.zip to /content
# 100% 5.10G/5.11G [00:37<00:00, 191MB/s]
# 100% 5.11G/5.11G [00:37<00:00, 148MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/lyft-udacity-challenge.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 12.6 MB/s eta 0:00:00
# Collecting typeguard<3.0.0,>=2.7
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.1)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.20.0 typeguard-2.13.3

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from keras import layers
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dropout 
from keras.layers import Conv2DTranspose
from keras.layers import concatenate
import os
import numpy as np 
import pandas as pd 

import imageio.v2 as imageio

import matplotlib.pyplot as plt
# %matplotlib inline

from keras.callbacks import ModelCheckpoint
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.layers.core import Activation, Reshape
from keras.models import Model
from keras.layers import BatchNormalization
import tensorflow_addons as tfa
from google.colab import files
import json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-fad8b0d5bc37> in <cell line: 25>()
#      23 from keras.models import Model
#      24 from keras.layers import BatchNormalization
# ---> 25 import tensorflow_addons as tfa
#      26 from google.colab import files
#      27 import json
#
# ModuleNotFoundError: No module named 'tensorflow_addons'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
image_path = ('/content/dataA/dataA/CameraRGB/')
mask_path = ('/content/dataA/dataA/CameraSeg/')
test_path = ('/content/dataB/dataB/CameraRGB/')
test_mask = ('/content/dataB/dataB/CameraSeg/')
image_list = sorted(os.listdir(image_path))
mask_list = sorted(os.listdir(mask_path))
test_image_list = sorted(os.listdir(test_path))
test_mask_list = sorted(os.listdir(test_mask))
image_list = [image_path+i for i in image_list]
mask_list = [mask_path+i for i in mask_list]
test_image_list = [test_path+i for i in test_image_list]
test_mask_list = [test_mask+i for i in test_mask_list]
img =  imageio.imread(image_list[12])
mask = imageio.imread(mask_list[12])


fig, arr = plt.subplots(1, 2, figsize=(14, 10))
arr[0].imshow(img)
arr[0].set_title('Image')
arr[1].imshow(mask[:,:,0])
arr[1].set_title('Segmentation')
# Out:
# Text(0.5, 1.0, 'Segmentation')

# %%
len(test_mask_list)
# Out:
# 1000

# %%
image_list_ds = tf.data.Dataset.list_files(image_list, shuffle=False)
mask_list_ds = tf.data.Dataset.list_files(mask_list, shuffle=False)
test_image_list_ds = tf.data.Dataset.list_files(test_image_list, shuffle=False)
test_mask_list_ds = tf.data.Dataset.list_files(test_mask_list, shuffle=False)


image_filenames = tf.constant(image_list)
masks_filenames = tf.constant(mask_list)
test_image_filenames = tf.constant(test_image_list)
test_masks_filenames = tf.constant(test_mask_list)
dataset = tf.data.Dataset.from_tensor_slices((image_filenames, masks_filenames))
test_dataset = tf.data.Dataset.from_tensor_slices((test_image_filenames, test_masks_filenames))

for image, mask in dataset.take(1):
    print(image)
    print(mask)
# Out:
# tf.Tensor(b'/content/dataA/dataA/CameraRGB/02_00_000.png', shape=(), dtype=string)
# tf.Tensor(b'/content/dataA/dataA/CameraSeg/02_00_000.png', shape=(), dtype=string)

# %%
def process_path(image_path, mask_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32) #/255

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=3)
    mask = tf.math.reduce_max(mask, axis=-1, keepdims=True) #/255
    return img, mask

def preprocess(image, mask):
    input_image = tf.image.resize(image, (256, 256), method='nearest')
    input_mask = tf.image.resize(mask, (256, 256), method='nearest')

    return input_image, input_mask

image_ds = dataset.map(process_path)
test_image_ds = test_dataset.map(process_path)
processed_image_ds = image_ds.map(preprocess)
test_processed_image_ds = test_image_ds.map(preprocess)

# %% [markdown]
# UNET model  input 256*256 classes 23

# %%
def double_conv_block(x, n_filters):
    x = layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
    x = layers.Conv2D(n_filters, 3, padding = "same", activation = "relu", kernel_initializer = "he_normal")(x)
    return x

# %%
def downsample_block(x, n_filters):
    f = double_conv_block(x, n_filters)
    p = layers.MaxPool2D(2)(f)
    p = layers.Dropout(0.3)(p)
    return f, p

# %%
def upsample_block(x, conv_features, n_filters):    
    x = layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x) # upsample
    # x = layers.concatenate([x, conv_features]) # concatenate
    x = layers.Dropout(0.3)(x)
    x = double_conv_block(x, n_filters)
    return x

# %%
def first_unet_model():
    inputs = layers.Input(shape=(256,256,3))
    # encoder
    f1, p1 = downsample_block(inputs, 64)
    f2, p2 = downsample_block(p1, 128)
    f3, p3 = downsample_block(p2, 256)
    f4, p4 = downsample_block(p3, 512)
    # bottleneck
    bottleneck = double_conv_block(p4, 1024)
    # decoder
    u6 = upsample_block(bottleneck, f4, 512)
    u7 = upsample_block(u6, f3, 256)
    u8 = upsample_block(u7, f2, 128)
    u9 = upsample_block(u8, f1, 64)
    # output
    outputs = layers.Conv2D(23, 1, padding="same", activation = "softmax")(u9)
    # model
    unet_model = tf.keras.Model(inputs, outputs, name="U-Net")
    return unet_model

# %%
unet_model = first_unet_model()
unet_model.summary()
# Out:
# Model: "U-Net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 256, 256, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 64)     0
#  )
#
#  dropout (Dropout)           (None, 128, 128, 64)      0
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 128)     147584
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 256)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 32, 32, 256)       0
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 512)       1180160
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 512)       2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 512)      0
#  2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 512)       0
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 1024)      4719616
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 1024)      9438208
#
#  conv2d_transpose (Conv2DTra  (None, 32, 32, 512)      4719104
#  nspose)
#
#  dropout_4 (Dropout)         (None, 32, 32, 512)       0
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 512)       2359808
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 512)       2359808
#
#  conv2d_transpose_1 (Conv2DT  (None, 64, 64, 256)      1179904
#  ranspose)
#
#  dropout_5 (Dropout)         (None, 64, 64, 256)       0
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 256)       590080
#
#  conv2d_13 (Conv2D)          (None, 64, 64, 256)       590080
#
#  conv2d_transpose_2 (Conv2DT  (None, 128, 128, 128)    295040
#  ranspose)
#
#  dropout_6 (Dropout)         (None, 128, 128, 128)     0
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 128)     147584
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 128)     147584
#
#  conv2d_transpose_3 (Conv2DT  (None, 256, 256, 64)     73792
#  ranspose)
#
#  dropout_7 (Dropout)         (None, 256, 256, 64)      0
#
#  conv2d_16 (Conv2D)          (None, 256, 256, 64)      36928
#
#  conv2d_17 (Conv2D)          (None, 256, 256, 64)      36928
#
#  conv2d_18 (Conv2D)          (None, 256, 256, 23)      1495
#
# =================================================================
# Total params: 31,381,335
# Trainable params: 31,381,335
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(unet_model, show_shapes=True)

# %% [markdown]
# Losses and Callbacks

# %%
class UpdatedMeanIoU(tf.keras.metrics.MeanIoU):
  def __init__(self,
               y_true=None,
               y_pred=None,
               num_classes=None,
               name=None,
               dtype=None):
    super(UpdatedMeanIoU, self).__init__(num_classes = 23,name=name, dtype=dtype)

  def update_state(self, y_true, y_pred, sample_weight=None):
    y_pred = tf.math.argmax(y_pred, axis=-1)
    return super().update_state(y_true, y_pred, sample_weight)

# %%
checkpoint_dir = '/content/drive/MyDrive/checkpoints'


checkpoint_callback = ModelCheckpoint(
    filepath=os.path.join(checkpoint_dir, 'weights_{epoch:02d}.h5'),
    save_weights_only=True,
    verbose=1
)

# %% [markdown]
# Compile the model

# %%
unet_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[UpdatedMeanIoU(),'accuracy'])

# %%
def display(display_list):
    plt.figure(figsize=(15, 15))
    title = ['Input Image', 'True Mask', 'Predicted Mask']
    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis('off')
    plt.show()

# %%
for image, mask in processed_image_ds.take(1):
    sample_image, sample_mask = image, mask
display([sample_image, sample_mask])

# %% [markdown]
# Run the model

# %%
EPOCHS = 50
VAL_SUBSPLITS = 10
BUFFER_SIZE = 500
BATCH_SIZE = 32
train_dataset = processed_image_ds.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
tests_dataset = test_processed_image_ds.cache().batch(BATCH_SIZE)
print(processed_image_ds.element_spec)
model_history = unet_model.fit(
    train_dataset,
    validation_data=tests_dataset,
    epochs=EPOCHS,
    callbacks=[checkpoint_callback]
)
# Out:
# (TensorSpec(shape=(256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(256, 256, 1), dtype=tf.uint8, name=None))
# Epoch 1/50
# 32/32 [==============================] - ETA: 0s - loss: 1729.8074 - updated_mean_io_u: 0.0167 - accuracy: 0.1487
# Epoch 1: saving model to /content/drive/MyDrive/checkpoints/weights_01.h5
# 32/32 [==============================] - 149s 3s/step - loss: 1729.8074 - updated_mean_io_u: 0.0167 - accuracy: 0.1487 - val_loss: 3.0674 - val_updated_mean_io_u: 0.0156 - val_accuracy: 0.1959
# Epoch 2/50
# 32/32 [==============================] - ETA: 0s - loss: 2.6278 - updated_mean_io_u: 0.0266 - accuracy: 0.1843
# Epoch 2: saving model to /content/drive/MyDrive/checkpoints/weights_02.h5
# 32/32 [==============================] - 67s 2s/step - loss: 2.6278 - updated_mean_io_u: 0.0266 - accuracy: 0.1843 - val_loss: 3.2430 - val_updated_mean_io_u: 0.0175 - val_accuracy: 0.1987
# Epoch 3/50
# 32/32 [==============================] - ETA: 0s - loss: 2.2851 - updated_mean_io_u: 0.0364 - accuracy: 0.2368
# Epoch 3: saving model to /content/drive/MyDrive/checkpoints/weights_03.h5
# 32/32 [==============================] - 67s 2s/step - loss: 2.2851 - updated_mean_io_u: 0.0364 - accuracy: 0.2368 - val_loss: 2.3895 - val_updated_mean_io_u: 0.0229 - val_accuracy: 0.1924
# Epoch 4/50
# 32/32 [==============================] - ETA: 0s - loss: 2.0527 - updated_mean_io_u: 0.0386 - accuracy: 0.2570
# Epoch 4: saving model to /content/drive/MyDrive/checkpoints/weights_04.h5
# 32/32 [==============================] - 67s 2s/step - loss: 2.0527 - updated_mean_io_u: 0.0386 - accuracy: 0.2570 - val_loss: 2.1886 - val_updated_mean_io_u: 0.0534 - val_accuracy: 0.2875
# Epoch 5/50
# 32/32 [==============================] - ETA: 0s - loss: 1.8850 - updated_mean_io_u: 0.0475 - accuracy: 0.2939
# Epoch 5: saving model to /content/drive/MyDrive/checkpoints/weights_05.h5
# 32/32 [==============================] - 73s 2s/step - loss: 1.8850 - updated_mean_io_u: 0.0475 - accuracy: 0.2939 - val_loss: 2.0976 - val_updated_mean_io_u: 0.0822 - val_accuracy: 0.3558
# Epoch 6/50
# 32/32 [==============================] - ETA: 0s - loss: 1.7466 - updated_mean_io_u: 0.0669 - accuracy: 0.3653
# Epoch 6: saving model to /content/drive/MyDrive/checkpoints/weights_06.h5
# 32/32 [==============================] - 67s 2s/step - loss: 1.7466 - updated_mean_io_u: 0.0669 - accuracy: 0.3653 - val_loss: 1.8482 - val_updated_mean_io_u: 0.1304 - val_accuracy: 0.4680
# Epoch 7/50
# 32/32 [==============================] - ETA: 0s - loss: 1.6236 - updated_mean_io_u: 0.1140 - accuracy: 0.5503
# Epoch 7: saving model to /content/drive/MyDrive/checkpoints/weights_07.h5
# 32/32 [==============================] - 66s 2s/step - loss: 1.6236 - updated_mean_io_u: 0.1140 - accuracy: 0.5503 - val_loss: 1.7073 - val_updated_mean_io_u: 0.1407 - val_accuracy: 0.5031
# Epoch 8/50
# 32/32 [==============================] - ETA: 0s - loss: 1.4692 - updated_mean_io_u: 0.1524 - accuracy: 0.6814
# Epoch 8: saving model to /content/drive/MyDrive/checkpoints/weights_08.h5
# 32/32 [==============================] - 67s 2s/step - loss: 1.4692 - updated_mean_io_u: 0.1524 - accuracy: 0.6814 - val_loss: 1.5311 - val_updated_mean_io_u: 0.1515 - val_accuracy: 0.5973
# Epoch 9/50
# 32/32 [==============================] - ETA: 0s - loss: 1.3663 - updated_mean_io_u: 0.1601 - accuracy: 0.6987
# Epoch 9: saving model to /content/drive/MyDrive/checkpoints/weights_09.h5
# 32/32 [==============================] - 67s 2s/step - loss: 1.3663 - updated_mean_io_u: 0.1601 - accuracy: 0.6987 - val_loss: 1.3722 - val_updated_mean_io_u: 0.1706 - val_accuracy: 0.6361
# Epoch 10/50
# 32/32 [==============================] - ETA: 0s - loss: 1.2660 - updated_mean_io_u: 0.1736 - accuracy: 0.7202
# Epoch 10: saving model to /content/drive/MyDrive/checkpoints/weights_10.h5
# 32/32 [==============================] - 67s 2s/step - loss: 1.2660 - updated_mean_io_u: 0.1736 - accuracy: 0.7202 - val_loss: 1.3776 - val_updated_mean_io_u: 0.1899 - val_accuracy: 0.6551
# Epoch 11/50
# 32/32 [==============================] - ETA: 0s - loss: 1.1762 - updated_mean_io_u: 0.1929 - accuracy: 0.7456
# Epoch 11: saving model to /content/drive/MyDrive/checkpoints/weights_11.h5
# 32/32 [==============================] - 67s 2s/step - loss: 1.1762 - updated_mean_io_u: 0.1929 - accuracy: 0.7456 - val_loss: 1.6744 - val_updated_mean_io_u: 0.2077 - val_accuracy: 0.6345
# Epoch 12/50
# 32/32 [==============================] - ETA: 0s - loss: 1.1035 - updated_mean_io_u: 0.2074 - accuracy: 0.7602
# Epoch 12: saving model to /content/drive/MyDrive/checkpoints/weights_12.h5
# 32/32 [==============================] - 67s 2s/step - loss: 1.1035 - updated_mean_io_u: 0.2074 - accuracy: 0.7602 - val_loss: 1.0694 - val_updated_mean_io_u: 0.2537 - val_accuracy: 0.7401
# Epoch 13/50
# 32/32 [==============================] - ETA: 0s - loss: 0.9946 - updated_mean_io_u: 0.2287 - accuracy: 0.7821
# Epoch 13: saving model to /content/drive/MyDrive/checkpoints/weights_13.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.9946 - updated_mean_io_u: 0.2287 - accuracy: 0.7821 - val_loss: 1.0023 - val_updated_mean_io_u: 0.2630 - val_accuracy: 0.7551
# Epoch 14/50
# 32/32 [==============================] - ETA: 0s - loss: 0.8996 - updated_mean_io_u: 0.2440 - accuracy: 0.8028
# Epoch 14: saving model to /content/drive/MyDrive/checkpoints/weights_14.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.8996 - updated_mean_io_u: 0.2440 - accuracy: 0.8028 - val_loss: 0.8658 - val_updated_mean_io_u: 0.3186 - val_accuracy: 0.8202
# Epoch 15/50
# 32/32 [==============================] - ETA: 0s - loss: 0.8284 - updated_mean_io_u: 0.2563 - accuracy: 0.8231
# Epoch 15: saving model to /content/drive/MyDrive/checkpoints/weights_15.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.8284 - updated_mean_io_u: 0.2563 - accuracy: 0.8231 - val_loss: 0.8669 - val_updated_mean_io_u: 0.3047 - val_accuracy: 0.8011
# Epoch 16/50
# 32/32 [==============================] - ETA: 0s - loss: 0.7801 - updated_mean_io_u: 0.2635 - accuracy: 0.8341
# Epoch 16: saving model to /content/drive/MyDrive/checkpoints/weights_16.h5
# 32/32 [==============================] - 73s 2s/step - loss: 0.7801 - updated_mean_io_u: 0.2635 - accuracy: 0.8341 - val_loss: 1.2068 - val_updated_mean_io_u: 0.2996 - val_accuracy: 0.7819
# Epoch 17/50
# 32/32 [==============================] - ETA: 0s - loss: 0.7706 - updated_mean_io_u: 0.2563 - accuracy: 0.8241
# Epoch 17: saving model to /content/drive/MyDrive/checkpoints/weights_17.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.7706 - updated_mean_io_u: 0.2563 - accuracy: 0.8241 - val_loss: 0.9419 - val_updated_mean_io_u: 0.3082 - val_accuracy: 0.7836
# Epoch 18/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6902 - updated_mean_io_u: 0.2740 - accuracy: 0.8498
# Epoch 18: saving model to /content/drive/MyDrive/checkpoints/weights_18.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.6902 - updated_mean_io_u: 0.2740 - accuracy: 0.8498 - val_loss: 0.9094 - val_updated_mean_io_u: 0.3172 - val_accuracy: 0.8055
# Epoch 19/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6408 - updated_mean_io_u: 0.2817 - accuracy: 0.8600
# Epoch 19: saving model to /content/drive/MyDrive/checkpoints/weights_19.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.6408 - updated_mean_io_u: 0.2817 - accuracy: 0.8600 - val_loss: 1.0597 - val_updated_mean_io_u: 0.3138 - val_accuracy: 0.7950
# Epoch 20/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6023 - updated_mean_io_u: 0.2866 - accuracy: 0.8661
# Epoch 20: saving model to /content/drive/MyDrive/checkpoints/weights_20.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.6023 - updated_mean_io_u: 0.2866 - accuracy: 0.8661 - val_loss: 0.9152 - val_updated_mean_io_u: 0.3197 - val_accuracy: 0.8016
# Epoch 21/50
# 32/32 [==============================] - ETA: 0s - loss: 0.5706 - updated_mean_io_u: 0.2905 - accuracy: 0.8704
# Epoch 21: saving model to /content/drive/MyDrive/checkpoints/weights_21.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.5706 - updated_mean_io_u: 0.2905 - accuracy: 0.8704 - val_loss: 1.2963 - val_updated_mean_io_u: 0.3065 - val_accuracy: 0.7752
# Epoch 22/50
# 32/32 [==============================] - ETA: 0s - loss: 0.5416 - updated_mean_io_u: 0.2942 - accuracy: 0.8743
# Epoch 22: saving model to /content/drive/MyDrive/checkpoints/weights_22.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.5416 - updated_mean_io_u: 0.2942 - accuracy: 0.8743 - val_loss: 1.0134 - val_updated_mean_io_u: 0.3230 - val_accuracy: 0.8029
# Epoch 23/50
# 32/32 [==============================] - ETA: 0s - loss: 0.5224 - updated_mean_io_u: 0.2964 - accuracy: 0.8759
# Epoch 23: saving model to /content/drive/MyDrive/checkpoints/weights_23.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.5224 - updated_mean_io_u: 0.2964 - accuracy: 0.8759 - val_loss: 0.9276 - val_updated_mean_io_u: 0.3336 - val_accuracy: 0.8072
# Epoch 24/50
# 32/32 [==============================] - ETA: 0s - loss: 0.4898 - updated_mean_io_u: 0.3024 - accuracy: 0.8827
# Epoch 24: saving model to /content/drive/MyDrive/checkpoints/weights_24.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.4898 - updated_mean_io_u: 0.3024 - accuracy: 0.8827 - val_loss: 0.6291 - val_updated_mean_io_u: 0.3543 - val_accuracy: 0.8462
# Epoch 25/50
# 32/32 [==============================] - ETA: 0s - loss: 0.4690 - updated_mean_io_u: 0.3054 - accuracy: 0.8852
# Epoch 25: saving model to /content/drive/MyDrive/checkpoints/weights_25.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.4690 - updated_mean_io_u: 0.3054 - accuracy: 0.8852 - val_loss: 0.8108 - val_updated_mean_io_u: 0.3506 - val_accuracy: 0.8299
# Epoch 26/50
# 32/32 [==============================] - ETA: 0s - loss: 0.4517 - updated_mean_io_u: 0.3085 - accuracy: 0.8881
# Epoch 26: saving model to /content/drive/MyDrive/checkpoints/weights_26.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.4517 - updated_mean_io_u: 0.3085 - accuracy: 0.8881 - val_loss: 1.6281 - val_updated_mean_io_u: 0.3245 - val_accuracy: 0.7762
# Epoch 27/50
# 32/32 [==============================] - ETA: 0s - loss: 0.4355 - updated_mean_io_u: 0.3321 - accuracy: 0.8905
# Epoch 27: saving model to /content/drive/MyDrive/checkpoints/weights_27.h5
# 32/32 [==============================] - 73s 2s/step - loss: 0.4355 - updated_mean_io_u: 0.3321 - accuracy: 0.8905 - val_loss: 1.0549 - val_updated_mean_io_u: 0.3426 - val_accuracy: 0.8078
# Epoch 28/50
# 32/32 [==============================] - ETA: 0s - loss: 0.4205 - updated_mean_io_u: 0.3144 - accuracy: 0.8928
# Epoch 28: saving model to /content/drive/MyDrive/checkpoints/weights_28.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.4205 - updated_mean_io_u: 0.3144 - accuracy: 0.8928 - val_loss: 0.6090 - val_updated_mean_io_u: 0.3600 - val_accuracy: 0.8478
# Epoch 29/50
# 32/32 [==============================] - ETA: 0s - loss: 0.4095 - updated_mean_io_u: 0.3164 - accuracy: 0.8938
# Epoch 29: saving model to /content/drive/MyDrive/checkpoints/weights_29.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.4095 - updated_mean_io_u: 0.3164 - accuracy: 0.8938 - val_loss: 0.8600 - val_updated_mean_io_u: 0.3591 - val_accuracy: 0.8325
# Epoch 30/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3992 - updated_mean_io_u: 0.3399 - accuracy: 0.8950
# Epoch 30: saving model to /content/drive/MyDrive/checkpoints/weights_30.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3992 - updated_mean_io_u: 0.3399 - accuracy: 0.8950 - val_loss: 0.8002 - val_updated_mean_io_u: 0.3624 - val_accuracy: 0.8370
# Epoch 31/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3871 - updated_mean_io_u: 0.3214 - accuracy: 0.8970
# Epoch 31: saving model to /content/drive/MyDrive/checkpoints/weights_31.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3871 - updated_mean_io_u: 0.3214 - accuracy: 0.8970 - val_loss: 1.2851 - val_updated_mean_io_u: 0.3565 - val_accuracy: 0.8157
# Epoch 32/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3782 - updated_mean_io_u: 0.3450 - accuracy: 0.8983
# Epoch 32: saving model to /content/drive/MyDrive/checkpoints/weights_32.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3782 - updated_mean_io_u: 0.3450 - accuracy: 0.8983 - val_loss: 0.7385 - val_updated_mean_io_u: 0.3766 - val_accuracy: 0.8452
# Epoch 33/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3690 - updated_mean_io_u: 0.3257 - accuracy: 0.8995
# Epoch 33: saving model to /content/drive/MyDrive/checkpoints/weights_33.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3690 - updated_mean_io_u: 0.3257 - accuracy: 0.8995 - val_loss: 0.9076 - val_updated_mean_io_u: 0.3688 - val_accuracy: 0.8292
# Epoch 34/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3598 - updated_mean_io_u: 0.3281 - accuracy: 0.9009
# Epoch 34: saving model to /content/drive/MyDrive/checkpoints/weights_34.h5
# 32/32 [==============================] - 74s 2s/step - loss: 0.3598 - updated_mean_io_u: 0.3281 - accuracy: 0.9009 - val_loss: 0.9580 - val_updated_mean_io_u: 0.3725 - val_accuracy: 0.8324
# Epoch 35/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3525 - updated_mean_io_u: 0.3302 - accuracy: 0.9021
# Epoch 35: saving model to /content/drive/MyDrive/checkpoints/weights_35.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3525 - updated_mean_io_u: 0.3302 - accuracy: 0.9021 - val_loss: 0.9383 - val_updated_mean_io_u: 0.3774 - val_accuracy: 0.8372
# Epoch 36/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3473 - updated_mean_io_u: 0.3542 - accuracy: 0.9026
# Epoch 36: saving model to /content/drive/MyDrive/checkpoints/weights_36.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3473 - updated_mean_io_u: 0.3542 - accuracy: 0.9026 - val_loss: 0.5654 - val_updated_mean_io_u: 0.3926 - val_accuracy: 0.8673
# Epoch 37/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3406 - updated_mean_io_u: 0.3566 - accuracy: 0.9034
# Epoch 37: saving model to /content/drive/MyDrive/checkpoints/weights_37.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3406 - updated_mean_io_u: 0.3566 - accuracy: 0.9034 - val_loss: 1.2061 - val_updated_mean_io_u: 0.3717 - val_accuracy: 0.8214
# Epoch 38/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3328 - updated_mean_io_u: 0.3598 - accuracy: 0.9051
# Epoch 38: saving model to /content/drive/MyDrive/checkpoints/weights_38.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3328 - updated_mean_io_u: 0.3598 - accuracy: 0.9051 - val_loss: 0.7037 - val_updated_mean_io_u: 0.4013 - val_accuracy: 0.8626
# Epoch 39/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3254 - updated_mean_io_u: 0.3641 - accuracy: 0.9065
# Epoch 39: saving model to /content/drive/MyDrive/checkpoints/weights_39.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3254 - updated_mean_io_u: 0.3641 - accuracy: 0.9065 - val_loss: 0.6590 - val_updated_mean_io_u: 0.4016 - val_accuracy: 0.8626
# Epoch 40/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3202 - updated_mean_io_u: 0.3666 - accuracy: 0.9073
# Epoch 40: saving model to /content/drive/MyDrive/checkpoints/weights_40.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3202 - updated_mean_io_u: 0.3666 - accuracy: 0.9073 - val_loss: 0.5660 - val_updated_mean_io_u: 0.4108 - val_accuracy: 0.8745
# Epoch 41/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3143 - updated_mean_io_u: 0.3475 - accuracy: 0.9086
# Epoch 41: saving model to /content/drive/MyDrive/checkpoints/weights_41.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3143 - updated_mean_io_u: 0.3475 - accuracy: 0.9086 - val_loss: 0.8207 - val_updated_mean_io_u: 0.4057 - val_accuracy: 0.8618
# Epoch 42/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3109 - updated_mean_io_u: 0.3994 - accuracy: 0.9089
# Epoch 42: saving model to /content/drive/MyDrive/checkpoints/weights_42.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3109 - updated_mean_io_u: 0.3994 - accuracy: 0.9089 - val_loss: 1.4011 - val_updated_mean_io_u: 0.3818 - val_accuracy: 0.8220
# Epoch 43/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3047 - updated_mean_io_u: 0.3772 - accuracy: 0.9103
# Epoch 43: saving model to /content/drive/MyDrive/checkpoints/weights_43.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3047 - updated_mean_io_u: 0.3772 - accuracy: 0.9103 - val_loss: 1.0747 - val_updated_mean_io_u: 0.3984 - val_accuracy: 0.8444
# Epoch 44/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2993 - updated_mean_io_u: 0.3814 - accuracy: 0.9114
# Epoch 44: saving model to /content/drive/MyDrive/checkpoints/weights_44.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.2993 - updated_mean_io_u: 0.3814 - accuracy: 0.9114 - val_loss: 1.1652 - val_updated_mean_io_u: 0.4037 - val_accuracy: 0.8453
# Epoch 45/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2962 - updated_mean_io_u: 0.3847 - accuracy: 0.9121
# Epoch 45: saving model to /content/drive/MyDrive/checkpoints/weights_45.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.2962 - updated_mean_io_u: 0.3847 - accuracy: 0.9121 - val_loss: 1.1014 - val_updated_mean_io_u: 0.4038 - val_accuracy: 0.8469
# Epoch 46/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2910 - updated_mean_io_u: 0.3636 - accuracy: 0.9132
# Epoch 46: saving model to /content/drive/MyDrive/checkpoints/weights_46.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.2910 - updated_mean_io_u: 0.3636 - accuracy: 0.9132 - val_loss: 0.9678 - val_updated_mean_io_u: 0.4141 - val_accuracy: 0.8588
# Epoch 47/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2879 - updated_mean_io_u: 0.4189 - accuracy: 0.9137
# Epoch 47: saving model to /content/drive/MyDrive/checkpoints/weights_47.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.2879 - updated_mean_io_u: 0.4189 - accuracy: 0.9137 - val_loss: 0.8549 - val_updated_mean_io_u: 0.4158 - val_accuracy: 0.8584
# Epoch 48/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2829 - updated_mean_io_u: 0.4227 - accuracy: 0.9149
# Epoch 48: saving model to /content/drive/MyDrive/checkpoints/weights_48.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.2829 - updated_mean_io_u: 0.4227 - accuracy: 0.9149 - val_loss: 1.3728 - val_updated_mean_io_u: 0.4005 - val_accuracy: 0.8309
# Epoch 49/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2777 - updated_mean_io_u: 0.3739 - accuracy: 0.9160
# Epoch 49: saving model to /content/drive/MyDrive/checkpoints/weights_49.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.2777 - updated_mean_io_u: 0.3739 - accuracy: 0.9160 - val_loss: 0.7418 - val_updated_mean_io_u: 0.4317 - val_accuracy: 0.8735
# Epoch 50/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2746 - updated_mean_io_u: 0.3769 - accuracy: 0.9167
# Epoch 50: saving model to /content/drive/MyDrive/checkpoints/weights_50.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.2746 - updated_mean_io_u: 0.3769 - accuracy: 0.9167 - val_loss: 1.1235 - val_updated_mean_io_u: 0.4244 - val_accuracy: 0.8500

# %%
def create_mask(pred_mask):
    pred_mask = tf.argmax(pred_mask, axis=-1)
    pred_mask = pred_mask[..., tf.newaxis]
    return pred_mask[0]

def show_predictions(dataset=None, num=1):
    if dataset:
        for image, mask in dataset.take(num):
            pred_mask = unet_model.predict(image)
            display([image[0], mask[0], create_mask(pred_mask)])
    else:
        display([sample_image, sample_mask,
             create_mask(unet_model.predict(sample_image[tf.newaxis, ...]))])

show_predictions(tests_dataset, 5)
# Out:
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 43ms/step

# %%
# save the history to a file
import json
history_file = 'history_unet_without_skip_256_lyft_dataset_50_epochs.json'
with open(history_file, 'w') as f:
    json.dump(model_history.history, f)
# download the history file
files.download(history_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8971694736cb> in <cell line: 4>()
#       3 history_file = 'history_unet_without_skip_256_lyft_dataset_50_epochs.json'
#       4 with open(history_file, 'w') as f:
# ----> 5     json.dump(model_history.history, f)
#       6 # download the history file
#       7 files.download(history_file)
#
# NameError: name 'model_history' is not defined
